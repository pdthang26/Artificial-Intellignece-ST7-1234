# %% [markdown]
# <a href="https://colab.research.google.com/github/pdthang26/Artificial-Intellignece-ST7-1234/blob/EXERCISE/Salary_Data_ST7_1234_ipynp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn import linear_model
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = "/content/Salary_Data.csv"

data = pd.read_csv(url)
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation = data.corr()
print(correlation)
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
sns.pairplot(data)

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame(data['YearsExperience'])
y =   data['Salary']
model.fit(X,y)
print('he so intercept la: ', model.intercept_)
print('he so coeffient la: ', model.coef_)            
print('do chinh xac cua mo hinh:',round(model.score(X,y)*100,7), '%') 

range = np.arange(0.5,15, 0.1)
X_range = pd.DataFrame(range)
y_pred = model.predict(X= X_range)
data.plot(kind = 'scatter', x= 'YearsExperience', y ='Salary', figsize= (9,9), color = "black", xlim = (0,15))
plt.plot(range, y_pred, color = 'green')
# Out:
# he so intercept la:  25792.200198668696
# he so coeffient la:  [9449.96232146]
# do chinh xac cua mo hinh: 95.6956664 %
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['YearsExperience'],data['YearsExperience']**2]).T
y =   data['Salary']
model.fit(X,y)
print('he so intercept la: ', model.intercept_)
print('he so coeffient la: ', model.coef_)            
print('do chinh xac cua mo hinh:', round(model.score(X,y)*100,7), '%') 

range = np.arange(0.5,15, 0.1)
X_range = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X= X_range)
data.plot(kind = 'scatter', x= 'YearsExperience', y ='Salary', figsize= (9,9), color = "black", xlim = (0,15))
plt.plot(range, y_pred, color = 'green')
# Out:
# he so intercept la:  26214.932677059565
# he so coeffient la:  [9259.2838882    16.39256632]
# do chinh xac cua mo hinh: 95.6975168 %
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['YearsExperience'],data['YearsExperience']**2,data['YearsExperience']**3,data['YearsExperience']**4]).T
y =   data['Salary']
model.fit(X,y)
print('he so intercept la: ', model.intercept_)
print('he so coeffient la: ', model.coef_)            
print('do chinh xac cua mo hinh:', round(model.score(X,y)*100,7), '%') 

range = np.arange(0.5,15, 0.1)
X_range = pd.DataFrame([range,range**2, range**3,range**4]).T
y_pred = model.predict(X= X_range)
data.plot(kind = 'scatter', x= 'YearsExperience', y ='Salary', figsize= (9,9), color = "black", xlim = (0,15))
plt.plot(range, y_pred, color = 'green')
# Out:
# he so intercept la:  41164.74839111141
# he so coeffient la:  [-3314.24649881  2979.91216451  -236.58640162     4.92429165]
# do chinh xac cua mo hinh: 96.365606 %
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['YearsExperience'],data['YearsExperience']**2,data['YearsExperience']**3,data['YearsExperience']**4,
                  data['YearsExperience']**5,data['YearsExperience']**6,data['YearsExperience']**7,data['YearsExperience']**8]).T
y =   data['Salary']
model.fit(X,y)
print('he so intercept la: ', model.intercept_)
print('he so coeffient la: ', model.coef_)            
print('do chinh xac cua mo hinh:', round(model.score(X,y)*100,7), '%') 

range = np.arange(1.5,10, 0.01)
X_range = pd.DataFrame([range,range**2, range**3,range**4, range**5,range**6, range**7,range**8]).T
y_pred = model.predict(X= X_range)
data.plot(kind = 'scatter', x= 'YearsExperience', y ='Salary', figsize= (9,9), color = "black", xlim = (0,15))
plt.plot(range, y_pred, color = 'green')
# Out:
# he so intercept la:  302702.1180290431
# he so coeffient la:  [-5.77066614e+05  4.87311654e+05 -2.08518697e+05  5.07784992e+04
#  -7.30086656e+03  6.13092844e+02 -2.78025800e+01  5.26086612e-01]
# do chinh xac cua mo hinh: 97.2815431 %
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['YearsExperience'],data['YearsExperience']**2,data['YearsExperience']**3,data['YearsExperience']**4,
                  data['YearsExperience']**5,data['YearsExperience']**6,data['YearsExperience']**7,data['YearsExperience']**8,
                  data['YearsExperience']**9,data['YearsExperience']**10,data['YearsExperience']**11,data['YearsExperience']**12,
                  data['YearsExperience']**13,data['YearsExperience']**14,data['YearsExperience']**15,data['YearsExperience']**16]).T
y =   data['Salary']
model.fit(X,y)
print('he so intercept la: ', model.intercept_)
print('he so coeffient la: ', model.coef_)            
print('do chinh xac cua mo hinh:', round(model.score(X,y)*100,7), '%') 

range = np.arange(1.5,10, 0.1)
X_range = pd.DataFrame([range,range**2, range**3,range**4, range**5,range**6, range**7,range**8,
                        range**9,range**10, range**11,range**12, range**13,range**14, range**15,range**16]).T
y_pred = model.predict(X= X_range)
data.plot(kind = 'scatter', x= 'YearsExperience', y ='Salary', figsize= (9,9), color = "black", xlim = (0,15))
plt.plot(range, y_pred, color = 'green')
# Out:
# he so intercept la:  38377.69607543945
# he so coeffient la:  [ 9.32623789e+00  2.39490448e+01  6.29294555e+01  1.09591197e+02
#   1.45227013e+02  1.17921742e+02 -1.18707428e+00 -8.79835171e+01
#   3.79600773e+01 -2.98266475e+00 -1.71852490e+00  5.67463118e-01
#  -8.06530700e-02  6.24172838e-03 -2.56962176e-04  4.42526896e-06]
# do chinh xac cua mo hinh: 97.9241395 %
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
