# %% [markdown]
# <a href="https://colab.research.google.com/github/pdthang26/Artificial-Intellignece-ST7-1234/blob/EXERCISE/AI_ST7_17_03_23_EXERCISE_50_STARTUP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = '/content/50_Startups.csv'

data =  pd.read_csv(url)
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
import matplotlib.pyplot as plt
data.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation = data.corr()
print(correlation)
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation, annot= True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
X = pd.DataFrame(data['R&D Spend'])
y= data['Profit']
model.fit(X, y)
print('he so intercept la: ', model.intercept_)
print('he so coeffient la: ', model.coef_)            
print('do chinh xac cua mo hinh:', model.score(X,y))  
import numpy as np
range = np.arange(1.50,200000, 10)
X_range = pd.DataFrame(range)
y_pred = model.predict(X= X_range)
data.plot(kind = 'scatter', x= 'R&D Spend', y ='Profit', figsize= (9,9), color = "black", xlim = (0,200000))
plt.plot(range, y_pred, color = 'green')
# Out:
# he so intercept la:  49032.89914125215
# he so coeffient la:  [0.85429137]
# do chinh xac cua mo hinh: 0.9465353160804393
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'], data['R&D Spend']**2]).T
y= data['Profit']
model.fit(X, y)
print('he so intercept la: ', model.intercept_)
print('he so coeffient la: ', model.coef_)            
print('do chinh xac cua mo hinh:', model.score(X,y))  
import numpy as np
range = np.arange(1.50,200000, 10)
X_range = pd.DataFrame([range, range**2]).T
y_pred = model.predict(X= X_range)
data.plot(kind = 'scatter', x= 'R&D Spend', y ='Profit', figsize= (9,9), color = "black", xlim = (0,200000))
plt.plot(range, y_pred, color = 'green')
# Out:
# he so intercept la:  48128.14916956878
# he so coeffient la:  [ 8.90147291e-01 -2.31821806e-07]
# do chinh xac cua mo hinh: 0.946703652909133
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'], data['R&D Spend']**2,data['R&D Spend']**3]).T
y= data['Profit']
model.fit(X, y)
print('he so intercept la: ', model.intercept_)
print('he so coeffient la: ', model.coef_)            
print('do chinh xac cua mo hinh:', model.score(X,y))  
import numpy as np
range = np.arange(1.50,200000, 10)
X_range = pd.DataFrame([range, range**2,range**3]).T
y_pred = model.predict(X= X_range)
data.plot(kind = 'scatter', x= 'R&D Spend', y ='Profit', figsize= (9,9), color = "black", xlim = (0,200000))
plt.plot(range, y_pred, color = 'green')
# Out:
# he so intercept la:  43108.76756818297
# he so coeffient la:  [ 1.40072682e+00 -8.82403324e-06  3.64774030e-11]
# do chinh xac cua mo hinh: 0.9540709421464032
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
model.fit(X= data.loc[:, ['R&D Spend', 'Marketing Spend']], y=data['Profit'])
print('he so intercept la: ', model.intercept_)
print('he so coeffient la: ', model.coef_)            
print('do chinh xac cua mo hinh:', round(model.score(X= data.loc[:, ['R&D Spend', 'Marketing Spend']], y=data['Profit'])*100,5), "%")
# Out:
# he so intercept la:  46975.86422071999
# he so coeffient la:  [0.79658404 0.02990788]
# do chinh xac cua mo hinh: 95.04503 %

# %%
model = linear_model.LinearRegression()
model.fit(X= data.loc[:, ['R&D Spend', 'Marketing Spend','Administration']], y=data['Profit'])
print('he so intercept la: ', model.intercept_)
print('he so coeffient la: ', model.coef_)            
print('do chinh xac cua mo hinh:', round(model.score(X= data.loc[:, ['R&D Spend', 'Marketing Spend','Administration']], y=data['Profit'])*100,5), "%")
# Out:
# he so intercept la:  50122.19298986525
# he so coeffient la:  [ 0.80571505  0.02722806 -0.02681597]
# do chinh xac cua mo hinh: 95.0746 %

# %%
model = linear_model.LinearRegression()
model.fit(X= data.loc[:, ['R&D Spend', 'Administration']], y=data['Profit'])
print('he so intercept la: ', model.intercept_)
print('he so coeffient la: ', model.coef_)            
print('do chinh xac cua mo hinh:', round(model.score(X= data.loc[:, ['R&D Spend', 'Administration']], y=data['Profit'])*100,5), "%")
# Out:
# he so intercept la:  54886.62062756297
# he so coeffient la:  [ 0.86211798 -0.05299543]
# do chinh xac cua mo hinh: 94.78129 %

# %%
model = linear_model.LinearRegression()
model.fit(X= data.loc[:, ['Administration', 'Marketing Spend']], y=data['Profit'])
print('he so intercept la: ', model.intercept_)
print('he so coeffient la: ', model.coef_)            
print('do chinh xac cua mo hinh:', round(model.score(X= data.loc[:, ['Administration', 'Marketing Spend']], y=data['Profit'])*100,5), "%")
# Out:
# he so intercept la:  20224.42905875767
# he so coeffient la:  [0.32367271 0.24884368]
# do chinh xac cua mo hinh: 60.9723 %
